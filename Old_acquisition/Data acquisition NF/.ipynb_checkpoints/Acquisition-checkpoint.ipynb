# %%
import sys
sys.path.append("./Dependencies/")
import pylablib.devices.DCAM as DCAM
import motors as mot
import shutter as shutt
import filter_wheels as fw
import matplotlib.pyplot as plt
import matlab.engine
from measure import *
import RotationMotor as rot
import os
from skimage.filters import median
from Setup_class import Setup
import ipywidgets as widgets
import numpy as np
from tifffile import imsave
from Acquisition_f import *

"________OPHIR_______"
import win32gui
import win32com.client
import time
import traceback

# %% [markdown]
# #  Connect setup

# %%
eng = matlab.engine.start_matlab()
eng.addpath('C:\\Users\\NEXT-BOLD\\Documents\\SERGIO\\Autofocus')
'''_______________Motors_____________________'''
conn, xdrive, ydrive = mot.start_drives()
connz, zdrive = mot.connectZdrive(com='COM5')
'''_________________Filter wheels______________'''
FWxC,_ = fw.connectLowFilters();
hdl = fw.Start_Low_FilterWheel(FWxC);
h_filters = fw.start_HighFilters(eng)
'''_______________Shutter_______________'''
h_shutter = shutt.connectShutter(eng)
'''______________Rotation motor_________________'''
h_rotor=rot.start_Rotor(eng)
'''______________Hamamatsu camera________________'''
cam = DCAM.DCAMCamera(idx=0)
cam.set_attribute_value("BINNING",4)
'''_______________Ophir power meter______________'''
OphirCOM = win32com.client.Dispatch("OphirLMMeasurement.CoLMMeasurement")
# Stop & Close all devices
OphirCOM.StopAllStreams() 
OphirCOM.CloseAll()
# Scan for connected Devices
DeviceList = OphirCOM.ScanUSB()
print(DeviceList)
for Device in DeviceList:   	# if any device is connected
    DeviceHandle = OphirCOM.OpenUSBDevice(Device)	# open first device
    exists = OphirCOM.IsSensorExists(DeviceHandle, 0)
    OphirCOM.SetRange(DeviceHandle, 0, 4)
# Out:
# Found Device 1 SN: 74596 (X-NA08A25-E09) -> Connection 1 (ASCII Serial port: COM6) devices
# Found Device 1 SN: 61516 (T-NA08A25) -> Connection 2 (Binary Serial port: COM5) devices
# hdl =  0
# Low filter wheel is opened,  1
# ('943894',)

# %% [markdown]
# # Define setup

# %%
stp = Setup(cam0=cam, eng=eng, h_filters=h_filters, h_rotor=h_rotor, shutter=h_shutter,
            xdrive=xdrive, ydrive=ydrive, zdrive=zdrive,Pmeter=OphirCOM,DeviceHandle=DeviceHandle)

# %% [markdown]
# # Control de potencia

# %%
stp.open_shutter()
stp.rotation(0)
stp.start_stream()
for i in range (0,90,5):
    stp.rotation(i)
p,t=stp.get_power()
stp.close_stream()
stp.close_shutter()

# %%
angle=(t-t[0])*90/(t[-1]-t[0])
plt.figure()
plt.plot(angle,p*1e6)
plt.xlabel("Angle")
plt.ylabel("Power($\mu$W)")
# Out:
# Text(0, 0.5, 'Power($\\mu$W)')

# %% [markdown]
# # New sample

# %%
New_sample()
# Out:
# Write the name of the sample:
# VS045_D1_Ba2
# Select molecule:
# ['None', 'G0', 'G0-Sl', 'G2', 'G2-Sl', 'Ir-Sl', 'Ru-Sl']
# None
#
#
# Select substrate:
# ['ITO', 'Quartz']
# Quartz
#
# Select deposition method:
# ['None', 'Evaporation', 'Spin Coating', 'Dip Coating']
# Spin Coating
#
# Add description (optional):
# VS045_D1 10e-4; ACN Ba2+ ANN175

# %% [markdown]
# # Enfoque

# %%
y0=17.2
z0=12.2
stp.set_y(y0)
stp.set_z(z0)
x0=20.05
x1=20.15
step=1

# %%
stp.set_exposure(0.1)
xs,arr,xpos=Autofocus(y0,z0,x0,x1,step,stp)

# %%
 # %matplotlib inline
plt.figure()
plt.plot(xs,arr)

# %%
# %matplotlib inline
posfocus=xpos
stp.open_shutter()
stp.set_filter(0)


stp.set_exposure(1)
stp.set_x(posfocus)
f=stp.frame()
plt.imshow(median(f))
plt.colorbar()
stp.close_shutter()

# %% [markdown]
# # Scanning

# %%
os.listdir(datapath)
# Out:
# ['G0_load_lock',
#  'G0_sample_prep',
#  'ITO',
#  'QUARTZ',
#  'VS022_D1',
#  'VS045_A1',
#  'VS045_D1_Ba2']

# %%
sample='VS045_D1_Ba2/'

# %%
ys=[16,17,18]
zs=[11,12,13]
Scan(ys,zs,xpos,0.1,1,15,sample,'VS045_D1_Ba',stp)
# Out:
# Has it Barium? (YES/NO)YES
# Description:VS045 with barium. 10e-4M. The good side is marked.

# %% [markdown]
# # Photobleaching

# %%
stp.close_stream()
stp.set_exposure(1)
data=Photobleaching(sample,'p0',100,0,1,stp)
# Out:
# [WinError 183] No se puede crear un archivo que ya existe: 'C:\\Users\\NEXT-BOLD\\Documents\\MIKEL\\LaserLab Dropbox/Proyectos/data/Data1/VS045_D1_Ba2//Microscope/Narrow Field/PHOTOBLEACHING/p0/'
# [WinError 183] No se puede crear un archivo que ya existe: 'C:\\Users\\NEXT-BOLD\\Documents\\MIKEL\\LaserLab Dropbox/Proyectos/data/Data1/VS045_D1_Ba2//Microscope/Narrow Field/PHOTOBLEACHING/p0/Filter0/'
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-39-206b3f4adb93> in <module>
#       1 stp.close_stream()
#       2 stp.set_exposure(1)
# ----> 3 data=Photobleaching(sample,'p0',100,0,1,stp)
#
# ~\Documents\MIKEL\LaserLab Dropbox\Proyectos\Data acquisition NF\Acquisition_f.py in Photobleaching(sample, name, N, filt, waitT, stp)
#      65     ppath=runpath+'Filter{}/'.format(filt)
#      66     create_folder(ppath)
# ---> 67     Temporal_evolution(ppath,N,filt,waitT,stp)
#      68
#      69
#
# ~\Documents\MIKEL\LaserLab Dropbox\Proyectos\Data acquisition NF\Acquisition_f.py in Temporal_evolution(ppath, N, filt, waitT, stp)
#      74     stp.start_stream()
#      75     for i in range(0,N):
# ---> 76         f=stp.frame()
#      77         np.savetxt(ppath+'Exp{:.2f}_wait{}_{}'.format(stp.get_exposure(),waitT,i),f)
#      78         data=np.append(data,np.sum(f))
#
# ~\Documents\MIKEL\LaserLab Dropbox\Proyectos\Data acquisition NF\Dependencies\Setup_class.py in frame(self)
#      33     def frame(self):
#      34         texp=self.get_exposure()
# ---> 35         return self.cam0.snap(timeout=texp+1)
#      36     def set_x(self,pos):
#      37         self.ydrive.move_absolute(pos, Units.LENGTH_MILLIMETRES)
#
# ~\anaconda3\lib\site-packages\pylablib\devices\interface\camera.py in snap(self, timeout, return_info)
#     675     def snap(self, timeout=5., return_info=False):
#     676         """Snap a single frame"""
# --> 677         res=self.grab(frame_timeout=timeout,return_info=return_info)
#     678         if return_info:
#     679             return _first_frame(*res)
#
# ~\anaconda3\lib\site-packages\pylablib\devices\interface\camera.py in grab(self, nframes, frame_timeout, missing_frame, return_info, buff_size)
#     661         try:
#     662             while nacq<nframes:
# --> 663                 self.wait_for_frame(timeout=frame_timeout)
#     664                 if return_info:
#     665                     new_frames,new_info,rng=self.read_multiple_images(missing_frame=missing_frame,return_info=True,return_rng=True)
#
# ~\anaconda3\lib\site-packages\pylablib\core\devio\interface.py in wrapped(*args, **kwargs)
#     662         def wrapped(*args, **kwargs):
#     663             all_args=parse_args(args,kwargs)
# --> 664             res=func(**all_args)
#     665             return parse_reply(res,args,kwargs)
#     666         def wrapped_wip(*args, **kwargs):
#
# ~\anaconda3\lib\site-packages\pylablib\devices\interface\camera.py in wait_for_frame(self, since, nframes, timeout, error_on_stopped)
#     261             if to is not None and to<=0:
#     262                 raise self.TimeoutError
# --> 263             self._wait_for_next_frame(timeout=to,idx=acquired_frames)
#     264         self._frame_counter.wait_done()
#     265         return True
#
# ~\anaconda3\lib\site-packages\pylablib\devices\DCAM\DCAM.py in _wait_for_next_frame(self, timeout, idx)
#     505         try:
#     506             eventmask=dcamapi4_lib.DCAMWAIT_EVENT.DCAMWAIT_CAPEVENT_FRAMEREADY
# --> 507             lib.dcamwait_start(self.dcamwait.hwait,eventmask,int(timeout*1000))
#     508             return
#     509         except DCAMLibError as e:
#
# <string> in <lambda>(hWait, eventmask, timeout)
#
# ~\anaconda3\lib\site-packages\pylablib\core\utils\ctypes_wrap.py in wrapped_func(*vargs, **kwargs)
#     276                     return a
#     277             call_args=[_to_call_arg(n,t,a) for (n,t,a) in zip(argnames,prep_argtypes,func_args)]
# --> 278             retval=func(*call_args)
#     279             res=self._convert_results(rvals or [None],dict(zip(argnames,func_args)),retval,kwargs,rconv)
#     280             if (not self.tuple_single_retval) and len(res)==0:
#
# ~\anaconda3\lib\site-packages\pylablib\devices\DCAM\dcamapi4_lib.py in errchecker(result, func, arguments)
#      36     """
#      37     passing=set(passing) if passing is not None else set()
# ---> 38     def errchecker(result, func, arguments):  # pylint: disable=unused-argument
#      39         if isinstance(result,tuple):
#      40             code,result=result[0],result[1:]
#
# KeyboardInterrupt:

# %% [markdown]
# ## Power

# %%
stp.open_shutter()
stp.start_stream()
time.sleep(60)
p,t=stp.get_power()
stp.close_stream()
stp.close_shutter()
